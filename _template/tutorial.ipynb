# %% [markdown]
# # <Tutorial Title>
#
# Short intro: what this is, why it matters, what you'll build/understand by the end.

# %% [markdown]
# ## 1. Theory
#
# Explain the concept from first principles. Define notation before using it. Use LaTeX (`$...$`) for math.

# %% [markdown]
# ## 2. Visuals
#
# Build intuition with a plot, diagram, or animation before diving into code.

# %%
import numpy as np
import matplotlib.pyplot as plt

# visualization goes here

# %% [markdown]
# ## 3. Implementation
#
# Build the concept up incrementally, with explanation between cells — not a single wall of finished code.

# %%
# implementation goes here

# %% [markdown]
# ## 4. Use cases
#
# Where does this show up in real systems? What are its limitations and tradeoffs vs alternatives?

# %% [markdown]
# ## References
#
# -
